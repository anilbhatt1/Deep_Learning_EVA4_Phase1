# %% [markdown]
# <a href="https://colab.research.google.com/github/anilbhatt1/Deep_Learning_EVA4_Phase1/blob/master/S13_YoloV3_Finding_Nemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/anilbhatt1/YoloV3.git
# Out:
# fatal: destination path 'YoloV3' already exists and is not an empty directory.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.4.0 _CudaDeviceProperties(name='Tesla P4', major=6, minor=1, total_memory=7611MB, multi_processor_count=20)

# %%
ls
# Out:
# gdrive/  sample_data/  YoloV3/

# %%
cd YoloV3/
# Out:
# /content/YoloV3

# %%
# !ls
# Out:
#  annotation_tool   output	  runs		   utils
#  cfg		   __pycache__	  test.py	   vim.exe.stackdump
#  data		   README.md	  ting		   weights
#  detect.py	   results.json   train.py
#  models.py	   results.png	 'ubdivisions=1'

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=3, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P4', total_memory=7611MB)
#
# 2020-04-25 07:41:59.751685: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 7129.53it/s]
# Caching images (0.0GB): 100% 20/20 [00:00<00:00, 135.04it/s]
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=300, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P4', total_memory=7611MB)
#
# 2020-04-25 07:45:21.336851: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (500 found, 0 missing, 2 empty, 0 duplicate, for 502 images): 100% 502/502 [00:00<00:00, 9931.09it/s]
# Caching images (0.3GB): 100% 502/502 [00:01<00:00, 289.25it/s]
# Reading image shapes: 100% 502/502 [00:00<00:00, 12392.68it/s]
# ...

# %%
# !cp -r /content/YoloV3/weights/last.pt /content/sample_data

# %%
# !python detect.py --conf-thres 0.1 --output "/content/gdrive/My Drive/Yolo_V3/Output_Annotated_Video" --source "/content/gdrive/My Drive/Yolo_V3/Input_Video/Finding_Nemo_Video.mp4"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/gdrive/My Drive/Yolo_V3/Output_Annotated_Video', save_txt=False, source='/content/gdrive/My Drive/Yolo_V3/Input_Video/Finding_Nemo_Video.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P4', total_memory=7611MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/1669) /content/gdrive/My Drive/Yolo_V3/Input_Video/Finding_Nemo_Video.mp4: 320x512 1 Nemos, Done. (0.031s)
# video 1/1 (2/1669) /content/gdrive/My Drive/Yolo_V3/Input_Video/Finding_Nemo_Video.mp4: 320x512 1 Nemos, Done. (0.029s)
# video 1/1 (3/1669) /content/gdrive/My Drive/Yolo_V3/Input_Video/Finding_Nemo_Video.mp4: 320x512 1 Nemos, Done. (0.029s)
# ...
